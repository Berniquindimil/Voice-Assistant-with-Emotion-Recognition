# %% [markdown]
# # 📖 Introduction

# %% [markdown]
# The goal of this project is to develop a deep learning model that can accurately classify facial expressions into one of seven categories: Angry, Disgust, Fear, Happy, Sad, Surprise, and Neutral. We will use convolutional neural networks (CNNs) to train our model, as they have been shown to be effective in image classification tasks. Our approach involves training a CNN model from scratch on the FER-2013 dataset
#
# ![emotions.png](attachment:02a21be9-12eb-4595-a450-8414036bac30.png)

# %% [markdown]
# # 💾 Data

# %% [markdown]
# The FER-2013 dataset consists of 48x48 pixel grayscale images of faces that have been automatically registered to be centred and occupy a similar amount of space in each image. The dataset contains 24,400 images, with 22,968 examples in the training set and 1,432 examples in the public test set.

# %% [markdown]
# # 🛠 Preprocessing

# %% [markdown]
# In this section, we will be using both data generators and data augmentation to train a deep learning model for human emotion detection using the FER-2013 dataset. Due to the size and complexity of the dataset, it would be impractical to load all of the images into memory at once. Therefore, we will be using data generators to generate batches of images on-the-fly during training, which will allow us to efficiently train our model on the entire dataset.
#
# In addition, we will be applying various data augmentation techniques to the training images, such as rotation, shifting, and flipping. This will help to increase the size and diversity of our training set, which can improve the performance of our deep learning model. By introducing variability into the training process, data augmentation can also help to prevent overfitting, which occurs when the model becomes too closely tailored to the training set and performs poorly on new, unseen data.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = "/Users/bernardoquindimil/Code/Berniquindimil/Proyect/archive/train" # Directory containing the training data
test_dir = "/Users/bernardoquindimil/Code/Berniquindimil/Proyect/archive/test"  # Directory containing the validation data

# %%
train_datagen = ImageDataGenerator(
    width_shift_range = 0.1,        # Randomly shift the width of images by up to 10%
    height_shift_range = 0.1,       # Randomly shift the height of images by up to 10%
    horizontal_flip = True,         # Flip images horizontally at random
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
    validation_split = 0.2          # Set aside 20% of the data for validation
)

validation_datagen = ImageDataGenerator(
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
    validation_split = 0.2          # Set aside 20% of the data for validation
)

# %%
train_generator = train_datagen.flow_from_directory(
    directory = train_dir,           # Directory containing the training data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 64,                 # Number of images per batch
    color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "training"              # Uses the training subset of the data
)

validation_generator = validation_datagen.flow_from_directory(
    directory = test_dir,            # Directory containing the validation data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 64,                 # Number of images per batch
    color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "validation"            # Uses the validation subset of the data
)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 1432 images belonging to 7 classes.

# %% [markdown]
# # Modeling

# %% [markdown]
# ## CNN Model

# %% [markdown]
# To develop the CNN architecture, we will begin by defining the input layer and the number of filters in the first convolutional layer. Then, we will add additional convolutional layers with increasing numbers of filters, followed by max-pooling layers to reduce the spatial dimensions of the feature maps. After the convolutional layers, we will add fully connected layers with ReLU activation to classify the emotions.
#
# We will experiment with different numbers of convolutional layers, filter sizes, and fully connected layers to optimize the model performance. Additionally, we will use techniques such as dropout and batch normalization to prevent overfitting and improve the generalization capability of the model.

# %%
from tensorflow.keras.layers import Dense, Dropout, Flatten, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential
import tensorflow as tf 

# Define the model architecture
model = Sequential()

# Add a convolutional layer with 32 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
# Add a batch normalization layer
model.add(BatchNormalization())
# Add a second convolutional layer with 64 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
# Add a second batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a third convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a third batch normalization layer
model.add(BatchNormalization())
# Add a fourth convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a fourth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a fifth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a fifth batch normalization layer
model.add(BatchNormalization())
# Add a sixth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a sixth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Flatten the output of the convolutional layers
model.add(Flatten())
# Add a dense layer with 256 neurons and relu activation function
model.add(Dense(256, activation='relu'))
# Add a seventh batch normalization layer
model.add(BatchNormalization())
# Add a dropout layer with 0.5 dropout rate
model.add(Dropout(0.5))
# Add a dense layer with 7 neurons (one for each class) and softmax activation function
model.add(Dense(7, activation='softmax'))

# Compile the model with categorical cross-entropy loss, adam optimizer, and accuracy metric
model.compile(loss="categorical_crossentropy", optimizer= tf.keras.optimizers.Adam(learning_rate=0.0001), metrics=['accuracy'])
# Out:
# /Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the callback
checkpoint_callback = ModelCheckpoint(
    filepath='model_weights.weights.h5',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

# Train the model with the callback
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=50,
    validation_data=validation_generator,
    validation_steps=len(validation_generator),
    callbacks=[checkpoint_callback]
)
# Out:
# /Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.1617 - loss: 2.9349
# /Users/bernardoquindimil/miniconda3/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1: val_accuracy improved from -inf to 0.18226, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 124s 337ms/step - accuracy: 0.1617 - loss: 2.9344 - val_accuracy: 0.1823 - val_loss: 1.9945
# Epoch 2/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.2128 - loss: 2.4491
# Epoch 2: val_accuracy improved from 0.18226 to 0.34148, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 119s 331ms/step - accuracy: 0.2128 - loss: 2.4489 - val_accuracy: 0.3415 - val_loss: 1.7342
# Epoch 3/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.2461 - loss: 2.2215
# Epoch 3: val_accuracy improved from 0.34148 to 0.37291, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 113s 314ms/step - accuracy: 0.2461 - loss: 2.2214 - val_accuracy: 0.3729 - val_loss: 1.6587
# Epoch 4/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.2817 - loss: 2.0856
# Epoch 4: val_accuracy improved from 0.37291 to 0.37360, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 113s 315ms/step - accuracy: 0.2817 - loss: 2.0855 - val_accuracy: 0.3736 - val_loss: 1.6371
# Epoch 5/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.3139 - loss: 1.9690
# Epoch 5: val_accuracy improved from 0.37360 to 0.42807, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 113s 315ms/step - accuracy: 0.3139 - loss: 1.9690 - val_accuracy: 0.4281 - val_loss: 1.5166
# Epoch 6/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.3376 - loss: 1.8854
# Epoch 6: val_accuracy improved from 0.42807 to 0.43645, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 113s 315ms/step - accuracy: 0.3376 - loss: 1.8853 - val_accuracy: 0.4365 - val_loss: 1.4706
# Epoch 7/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.3584 - loss: 1.7969
# Epoch 7: val_accuracy improved from 0.43645 to 0.45601, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 113s 315ms/step - accuracy: 0.3584 - loss: 1.7969 - val_accuracy: 0.4560 - val_loss: 1.4383
# Epoch 8/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.3672 - loss: 1.7555
# Epoch 8: val_accuracy improved from 0.45601 to 0.46439, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 114s 317ms/step - accuracy: 0.3672 - loss: 1.7554 - val_accuracy: 0.4644 - val_loss: 1.3710
# Epoch 9/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.3907 - loss: 1.6775
# Epoch 9: val_accuracy improved from 0.46439 to 0.48464, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 117s 326ms/step - accuracy: 0.3907 - loss: 1.6775 - val_accuracy: 0.4846 - val_loss: 1.3824
# Epoch 10/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.4052 - loss: 1.6342
# Epoch 10: val_accuracy improved from 0.48464 to 0.49162, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 112s 312ms/step - accuracy: 0.4052 - loss: 1.6341 - val_accuracy: 0.4916 - val_loss: 1.3474
# Epoch 11/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.4327 - loss: 1.5599
# Epoch 11: val_accuracy improved from 0.49162 to 0.51606, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 112s 312ms/step - accuracy: 0.4327 - loss: 1.5599 - val_accuracy: 0.5161 - val_loss: 1.2787
# Epoch 12/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.4421 - loss: 1.5187
# Epoch 12: val_accuracy improved from 0.51606 to 0.53911, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 112s 311ms/step - accuracy: 0.4421 - loss: 1.5187 - val_accuracy: 0.5391 - val_loss: 1.2595
# Epoch 13/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.4529 - loss: 1.4747
# Epoch 13: val_accuracy did not improve from 0.53911
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 111s 310ms/step - accuracy: 0.4529 - loss: 1.4747 - val_accuracy: 0.5356 - val_loss: 1.2422
# Epoch 14/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.4642 - loss: 1.4340
# Epoch 14: val_accuracy did not improve from 0.53911
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 112s 312ms/step - accuracy: 0.4642 - loss: 1.4340 - val_accuracy: 0.5391 - val_loss: 1.1989
# Epoch 15/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.4759 - loss: 1.4006
# Epoch 15: val_accuracy improved from 0.53911 to 0.54749, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 1697s 5s/step - accuracy: 0.4759 - loss: 1.4006 - val_accuracy: 0.5475 - val_loss: 1.2024
# Epoch 16/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.4819 - loss: 1.3753
# Epoch 16: val_accuracy did not improve from 0.54749
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 113s 314ms/step - accuracy: 0.4819 - loss: 1.3752 - val_accuracy: 0.5454 - val_loss: 1.2052
# Epoch 17/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.4904 - loss: 1.3349
# Epoch 17: val_accuracy improved from 0.54749 to 0.56425, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 114s 317ms/step - accuracy: 0.4904 - loss: 1.3349 - val_accuracy: 0.5642 - val_loss: 1.1918
# Epoch 18/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.5028 - loss: 1.3109
# Epoch 18: val_accuracy did not improve from 0.56425
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 111s 309ms/step - accuracy: 0.5028 - loss: 1.3109 - val_accuracy: 0.5573 - val_loss: 1.1607
# Epoch 19/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.5142 - loss: 1.2921
# Epoch 19: val_accuracy improved from 0.56425 to 0.57263, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 112s 312ms/step - accuracy: 0.5142 - loss: 1.2920 - val_accuracy: 0.5726 - val_loss: 1.1278
# Epoch 20/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.5256 - loss: 1.2589
# Epoch 20: val_accuracy improved from 0.57263 to 0.57542, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 1639s 5s/step - accuracy: 0.5256 - loss: 1.2590 - val_accuracy: 0.5754 - val_loss: 1.1340
# Epoch 21/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.5239 - loss: 1.2632
# Epoch 21: val_accuracy did not improve from 0.57542
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 114s 318ms/step - accuracy: 0.5240 - loss: 1.2632 - val_accuracy: 0.5691 - val_loss: 1.1388
# Epoch 22/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.5313 - loss: 1.2432
# Epoch 22: val_accuracy improved from 0.57542 to 0.59008, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 114s 317ms/step - accuracy: 0.5313 - loss: 1.2431 - val_accuracy: 0.5901 - val_loss: 1.1016
# Epoch 23/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.5437 - loss: 1.2116
# Epoch 23: val_accuracy did not improve from 0.59008
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 112s 313ms/step - accuracy: 0.5437 - loss: 1.2116 - val_accuracy: 0.5831 - val_loss: 1.0986
# Epoch 24/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.5525 - loss: 1.1968
# Epoch 24: val_accuracy did not improve from 0.59008
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 113s 315ms/step - accuracy: 0.5525 - loss: 1.1968 - val_accuracy: 0.5859 - val_loss: 1.0795
# Epoch 25/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.5596 - loss: 1.1731
# Epoch 25: val_accuracy improved from 0.59008 to 0.60405, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 113s 313ms/step - accuracy: 0.5596 - loss: 1.1731 - val_accuracy: 0.6041 - val_loss: 1.0789
# Epoch 26/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.5664 - loss: 1.1566
# Epoch 26: val_accuracy improved from 0.60405 to 0.60754, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 111s 309ms/step - accuracy: 0.5664 - loss: 1.1566 - val_accuracy: 0.6075 - val_loss: 1.0659
# Epoch 27/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 866ms/step - accuracy: 0.5642 - loss: 1.1576
# Epoch 27: val_accuracy did not improve from 0.60754
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 312s 870ms/step - accuracy: 0.5642 - loss: 1.1576 - val_accuracy: 0.6020 - val_loss: 1.0641
# Epoch 28/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.5703 - loss: 1.1584
# Epoch 28: val_accuracy improved from 0.60754 to 0.61313, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 113s 315ms/step - accuracy: 0.5703 - loss: 1.1584 - val_accuracy: 0.6131 - val_loss: 1.0422
# Epoch 29/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.5801 - loss: 1.1211
# Epoch 29: val_accuracy did not improve from 0.61313
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 113s 314ms/step - accuracy: 0.5801 - loss: 1.1211 - val_accuracy: 0.5957 - val_loss: 1.0737
# Epoch 30/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.5794 - loss: 1.1103
# Epoch 30: val_accuracy improved from 0.61313 to 0.61732, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 112s 313ms/step - accuracy: 0.5794 - loss: 1.1103 - val_accuracy: 0.6173 - val_loss: 1.0337
# Epoch 31/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.5772 - loss: 1.1243
# Epoch 31: val_accuracy did not improve from 0.61732
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 112s 313ms/step - accuracy: 0.5772 - loss: 1.1243 - val_accuracy: 0.6082 - val_loss: 1.0537
# Epoch 32/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.5901 - loss: 1.1016
# Epoch 32: val_accuracy did not improve from 0.61732
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 112s 312ms/step - accuracy: 0.5900 - loss: 1.1016 - val_accuracy: 0.6082 - val_loss: 1.0444
# Epoch 33/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.5916 - loss: 1.0858
# Epoch 33: val_accuracy improved from 0.61732 to 0.61872, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 113s 313ms/step - accuracy: 0.5916 - loss: 1.0858 - val_accuracy: 0.6187 - val_loss: 1.0137
# Epoch 34/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.5915 - loss: 1.0799
# Epoch 34: val_accuracy improved from 0.61872 to 0.62151, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 112s 312ms/step - accuracy: 0.5915 - loss: 1.0799 - val_accuracy: 0.6215 - val_loss: 1.0049
# Epoch 35/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.5980 - loss: 1.0677
# Epoch 35: val_accuracy improved from 0.62151 to 0.63268, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 113s 316ms/step - accuracy: 0.5980 - loss: 1.0678 - val_accuracy: 0.6327 - val_loss: 0.9966
# Epoch 36/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6045 - loss: 1.0645
# Epoch 36: val_accuracy did not improve from 0.63268
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 1101s 3s/step - accuracy: 0.6045 - loss: 1.0646 - val_accuracy: 0.6236 - val_loss: 1.0014
# Epoch 37/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.6024 - loss: 1.0651
# Epoch 37: val_accuracy did not improve from 0.63268
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 3459s 10s/step - accuracy: 0.6024 - loss: 1.0651 - val_accuracy: 0.6306 - val_loss: 1.0161
# Epoch 38/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.6030 - loss: 1.0518
# Epoch 38: val_accuracy did not improve from 0.63268
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 112s 312ms/step - accuracy: 0.6030 - loss: 1.0518 - val_accuracy: 0.6208 - val_loss: 1.0154
# Epoch 39/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.6098 - loss: 1.0460
# Epoch 39: val_accuracy did not improve from 0.63268
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 113s 315ms/step - accuracy: 0.6098 - loss: 1.0460 - val_accuracy: 0.6327 - val_loss: 0.9896
# Epoch 40/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.6093 - loss: 1.0337
# Epoch 40: val_accuracy did not improve from 0.63268
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 113s 316ms/step - accuracy: 0.6093 - loss: 1.0337 - val_accuracy: 0.6299 - val_loss: 0.9914
# Epoch 41/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.6164 - loss: 1.0300
# Epoch 41: val_accuracy improved from 0.63268 to 0.64036, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 188s 525ms/step - accuracy: 0.6164 - loss: 1.0300 - val_accuracy: 0.6404 - val_loss: 0.9656
# Epoch 42/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.6257 - loss: 1.0119
# Epoch 42: val_accuracy did not improve from 0.64036
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 118s 328ms/step - accuracy: 0.6257 - loss: 1.0120 - val_accuracy: 0.6362 - val_loss: 0.9760
# Epoch 43/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.6178 - loss: 1.0104
# Epoch 43: val_accuracy did not improve from 0.64036
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 99s 277ms/step - accuracy: 0.6178 - loss: 1.0104 - val_accuracy: 0.6369 - val_loss: 0.9691
# Epoch 44/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.6259 - loss: 1.0006
# Epoch 44: val_accuracy improved from 0.64036 to 0.64246, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 100s 279ms/step - accuracy: 0.6259 - loss: 1.0006 - val_accuracy: 0.6425 - val_loss: 0.9779
# Epoch 45/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.6288 - loss: 0.9993
# Epoch 45: val_accuracy did not improve from 0.64246
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 100s 277ms/step - accuracy: 0.6288 - loss: 0.9993 - val_accuracy: 0.6425 - val_loss: 0.9725
# Epoch 46/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.6218 - loss: 1.0130
# Epoch 46: val_accuracy did not improve from 0.64246
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 98s 274ms/step - accuracy: 0.6218 - loss: 1.0129 - val_accuracy: 0.6369 - val_loss: 0.9622
# Epoch 47/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6267 - loss: 0.9988
# Epoch 47: val_accuracy improved from 0.64246 to 0.64804, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 915s 3s/step - accuracy: 0.6267 - loss: 0.9988 - val_accuracy: 0.6480 - val_loss: 0.9548
# Epoch 48/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6396 - loss: 0.9654
# Epoch 48: val_accuracy did not improve from 0.64804
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 521s 1s/step - accuracy: 0.6396 - loss: 0.9654 - val_accuracy: 0.6320 - val_loss: 0.9730
# Epoch 49/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.6400 - loss: 0.9659
# Epoch 49: val_accuracy did not improve from 0.64804
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 99s 276ms/step - accuracy: 0.6399 - loss: 0.9659 - val_accuracy: 0.6466 - val_loss: 0.9592
# Epoch 50/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.6404 - loss: 0.9575
# Epoch 50: val_accuracy improved from 0.64804 to 0.65293, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 104s 288ms/step - accuracy: 0.6404 - loss: 0.9575 - val_accuracy: 0.6529 - val_loss: 0.9416

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Training and validation loss curves

# %%
import matplotlib.pyplot as plt

# Plot the train and validation loss
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Training and validation accuracy curves

# %%
# Plot the train and validation accuracy
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, train_acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
import seaborn as sns 
from sklearn.metrics import confusion_matrix
import numpy as np

# Get the true labels and predicted labels for the validation set
validation_labels = validation_generator.classes
validation_pred_probs = model.predict(validation_generator)
validation_pred_labels = np.argmax(validation_pred_probs, axis=1)

# Compute the confusion matrix
confusion_mtx = confusion_matrix(validation_labels, validation_pred_labels)
class_names = list(train_generator.class_indices.keys())
sns.set()
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='YlGnBu', 
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
